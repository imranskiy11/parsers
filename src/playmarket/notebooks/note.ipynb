# %%
import pandas as pd
import random

# %%
# reviews = pd.read_csv('data/parsed/google_play_reviews.csv')
# reviews

# %%
reviews.review_text[1]
# Out:
# 'Планировщик задач. Можно создавать списки задач В том числе по времени на текущую дату на какую-то выбранную дату или просто на будущее. Каждая задача может быть дополнительно расширена. Программа обладает достаточно приятным интерфейсом. Главное, что она обладает виджетом, который всплывает на экране, и позволяет быстро добавить задачу, так этот виджет достаточно легко убрать, там есть крестик справа, нажимаешь на этот крестик и виджет, исчезает это окно, которое всплывает.'

# %%
# Out:
# 1.8674133656922784
